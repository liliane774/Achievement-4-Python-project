# %%
# Importing Libraries

import pandas as pd
import numpy as np
import os

# %%
# Import orders_product_combined dataframe from the pickle file 

orders_products_combined = pd.read_pickle(os.path.join(df_path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))

# Check shape of the imported dataframe
orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both          32434489
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Wrangled cleaned and deduped product data set
df_path='/Users/ryumugil/Downloads/CF/02-12-2025 Instacart Basket Analysis'

df_prods_clean_exported = pd.read_csv(os.path.join(df_path, '02 Data', 'Prepared Data','data_clean_products.csv'))
df_prods_clean_exported.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Combine the orders_products_combined dataframe with product data set ,which is wrangled,cleaned and deduped.

df_ords_prods_merged=orders_products_combined.merge(df_prods_clean_exported, how='left', on = 'product_id')

# Confirm the results of the merge using the merge flag
df_ords_prods_merged['_merge'].value_counts()
# Out:
# _merge
# both          32436241
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
df_ords_prods_merged.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2539329        1             1          2                  8
# 2   2539329        1             1          2                  8
# 3   2539329        1             1          2                  8
# 4   2539329        1             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both
#
#                               product_name  aisle_id  department_id  prices
# ...

# %%
# Check the size of ords_prods_merge data frame
df_ords_prods_merged.shape
# Out:
# (32436241, 14)

# %%
#Export ords_prods_merge dataframe as orders product merged .csv in Prepared Data.

# this exports the newly created dataframe into orders products merged.csv
df_ords_prods_merged.to_csv(os.path.join(df_path, '02 Data', 'Prepared Data','orders_products_merged.csv'), index=False)
